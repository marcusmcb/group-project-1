# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('city_median_rental_price.csv')
df.head(2)
# Out:
#     RegionName State                           Metro          CountyName  \
# 0     New York    NY     New York-Newark-Jersey City       Queens County
# 1  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles County
#
#    SizeRank  2010-01  2010-02  2010-03  2010-04  2010-05   ...     2018-05  \
# 0         1      NaN      NaN      NaN      NaN      NaN   ...      2600.0
# 1         2      NaN      NaN      NaN      NaN      NaN   ...      3950.0
#
#    2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  \
# 0   2595.0   2600.0   2600.0   2600.0   2599.0   2559.0   2500.0   2500.0
# 1   4100.0   4000.0   4000.0   4000.0   4000.0   4000.0   3995.0   3950.0
#
#    2019-02
# 0   2500.0
# 1   3980.0
#
# [2 rows x 115 columns]

# %%
df.tail(1)
# Out:
#      RegionName State                        Metro      CountyName  SizeRank  \
# 1427     Quogue    NY  New York-Newark-Jersey City  Suffolk County      1428
#
#       2010-01  2010-02  2010-03  2010-04  2010-05   ...     2018-05  2018-06  \
# 1427      NaN      NaN      NaN      NaN      NaN   ...     33250.0  31000.0
#
#       2018-07  2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02
# 1427  32000.0  35000.0  35000.0  36000.0  30000.0  30000.0  30000.0  30000.0
#
# [1 rows x 115 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Columns: 115 entries, RegionName to 2019-02
# dtypes: float64(110), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
df['RegionName'].nunique() #gives unique values in data code
# Out:
# 1315

# %%
df.describe()
# Out:
#           SizeRank  2010-01     2010-02      2010-03      2010-04  \
# count  1428.000000      1.0    20.00000    54.000000    63.000000
# mean    714.492297    925.0  1298.50000  1309.861111  1353.571429
# std     412.366881      NaN   341.06586   393.740054   504.554202
# min       1.000000    925.0   795.00000   795.000000   750.000000
# 25%     357.750000    925.0  1081.25000  1061.250000  1025.000000
# 50%     714.500000    925.0  1300.00000  1250.000000  1272.500000
# 75%    1071.250000    925.0  1446.25000  1398.750000  1472.500000
# max    1428.000000    925.0  2400.00000  2825.000000  3650.000000
#
#            2010-05      2010-06      2010-07      2010-08      2010-09  \
# count    69.000000    69.000000    73.000000    80.000000    86.000000
# mean   1369.746377  1386.108696  1374.212329  1372.756250  1366.732558
# std     492.650236   522.066798   515.171815   491.293114   482.839955
# min     772.500000   750.000000   750.000000   825.000000   809.000000
# ...

# %%
#df['RegionName'].value_counts()

# %%
median_prices = df.median()

# %%
median_prices.tail()
# Out:
# 2018-10    1600.00
# 2018-11    1600.00
# 2018-12    1600.00
# 2019-01    1625.00
# 2019-02    1636.25
# dtype: float64

# %%
#df[df.CountyName==Los_Angeles_County]

# %%
median_prices.plot()

# %%
sf_df = df[df["Metro"] == "Los Angeles-Long Beach-Anaheim"].median()
df_comparison = pd.concat([sf_df,median_prices], axis=1)
df_comparison.columns = ["Los Angeles-Long Beach-Anaheim","Median OC_LA"]
df_comparison.tail(4)
# Out:
#          Los Angeles-Long Beach-Anaheim  Median OC_LA
# 2018-11                          3147.5       1600.00
# 2018-12                          3195.0       1600.00
# 2019-01                          3100.0       1625.00
# 2019-02                          3100.0       1636.25

# %%
df_comparison.plot()
